# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("token_usage.csv")

# %%
df["task_id"] = df["task_id"].replace("20250215-120903", "survery Large Language Model papers")

# %%
df
# Out:
#      prompt_tokens  completion_tokens  cached_tokens  \
# 0             9891                527              0
# 1             1816                258              0
# 2             3548                106              0
# 3             9559                466              0
# 4             9891                558              0
# ..             ...                ...            ...
# 386           5370                 76              0
# 387           2972                 92              0
# 388           2190                146              0
# 389           1390                  6              0
# 390            759                173              0
#
#                                  task_id              model
# 0                        20250215-120638        gpt-4o-mini
# 1                        20250215-120638  gpt-4o-2024-11-20
# 2                        20250215-120638  gpt-4o-2024-11-20
# 3                        20250215-120638        gpt-4o-mini
# 4    survery Large Language Model papers        gpt-4o-mini
# ..                                   ...                ...
# 386                    2_recipes_chinese  gpt-4o-2024-11-20
# 387                    2_recipes_chinese  gpt-4o-2024-11-20
# 388                    2_recipes_chinese  gpt-4o-2024-11-20
# 389                    2_recipes_chinese  gpt-4o-2024-11-20
# 390                    2_recipes_chinese  gpt-4o-2024-11-20
#
# [391 rows x 5 columns]

# %%
s = df.groupby(by=["task_id","model"]).sum()

# %%
type(s)
# Out:
# pandas.core.frame.DataFrame

# %%
s= s.reset_index(drop=False)

# %%
s
# Out:
#                                 task_id              model  prompt_tokens  \
# 0                1_bakery_birthday_cake  gpt-4o-2024-11-20          21700
# 1                1_bakery_birthday_cake        gpt-4o-mini          26847
# 2              1_late_night_korean_food  gpt-4o-2024-11-20         351869
# 3              1_late_night_korean_food        gpt-4o-mini         381906
# 4                      1_nearest_bakery  gpt-4o-2024-11-20          22589
# 5                      1_nearest_bakery        gpt-4o-mini          41919
# 6                           1_thai_duck  gpt-4o-2024-11-20         255280
# 7                           1_thai_duck        gpt-4o-mini         241430
# 8                       20250215-120638  gpt-4o-2024-11-20           5364
# 9                       20250215-120638        gpt-4o-mini          19450
# 10                  2_llm_agents_survey  gpt-4o-2024-11-20         143199
# 11                  2_llm_agents_survey        gpt-4o-mini         102244
# 12                    2_recipes_chinese  gpt-4o-2024-11-20          45650
# 13                    2_recipes_chinese        gpt-4o-mini          45162
# 14             2_segment_anything_cited  gpt-4o-2024-11-20         182018
# 15             2_segment_anything_cited        gpt-4o-mini         136187
# 16  survery Large Language Model papers  gpt-4o-2024-11-20         121959
# 17  survery Large Language Model papers        gpt-4o-mini          83124
#
#     completion_tokens  cached_tokens
# 0                 686              0
# 1                1439              0
# 2               13742              0
# 3               18734              0
# 4                 625              0
# 5                2188              0
# 6               10780              0
# 7               11616              0
# 8                 364              0
# 9                 993              0
# 10               5184              0
# 11               4879              0
# 12               1516              0
# 13               2175              0
# 14               6398              0
# 15               6468              0
# 16               6170              0
# 17               4032              0

# %%
def cost_function(row):
    if (row["model"] == "gpt-4o-mini"):
        return row["prompt_tokens"]* 0.15/1000000.0 + 0.6 /1000000.0 * row["completion_tokens"]
    else:
        return row["prompt_tokens"]* 2.5/1000000.0 + 10.0 /1000000.0 * row["completion_tokens"]

# %%
s["cost"] = s.apply(cost_function, axis= 1)

# %%
s
# Out:
#                                 task_id              model  prompt_tokens  \
# 0                1_bakery_birthday_cake  gpt-4o-2024-11-20          21700
# 1                1_bakery_birthday_cake        gpt-4o-mini          26847
# 2              1_late_night_korean_food  gpt-4o-2024-11-20         351869
# 3              1_late_night_korean_food        gpt-4o-mini         381906
# 4                      1_nearest_bakery  gpt-4o-2024-11-20          22589
# 5                      1_nearest_bakery        gpt-4o-mini          41919
# 6                           1_thai_duck  gpt-4o-2024-11-20         255280
# 7                           1_thai_duck        gpt-4o-mini         241430
# 8                       20250215-120638  gpt-4o-2024-11-20           5364
# 9                       20250215-120638        gpt-4o-mini          19450
# 10                  2_llm_agents_survey  gpt-4o-2024-11-20         143199
# 11                  2_llm_agents_survey        gpt-4o-mini         102244
# 12                    2_recipes_chinese  gpt-4o-2024-11-20          45650
# 13                    2_recipes_chinese        gpt-4o-mini          45162
# 14             2_segment_anything_cited  gpt-4o-2024-11-20         182018
# 15             2_segment_anything_cited        gpt-4o-mini         136187
# 16  survery Large Language Model papers  gpt-4o-2024-11-20         121959
# 17  survery Large Language Model papers        gpt-4o-mini          83124
#
#     completion_tokens  cached_tokens      cost
# 0                 686              0  0.061110
# 1                1439              0  0.004890
# 2               13742              0  1.017092
# 3               18734              0  0.068526
# 4                 625              0  0.062723
# 5                2188              0  0.007601
# 6               10780              0  0.746000
# 7               11616              0  0.043184
# 8                 364              0  0.017050
# 9                 993              0  0.003513
# 10               5184              0  0.409838
# 11               4879              0  0.018264
# 12               1516              0  0.129285
# 13               2175              0  0.008079
# 14               6398              0  0.519025
# 15               6468              0  0.024309
# 16               6170              0  0.366598
# 17               4032              0  0.014888

# %%
s["cost"].sum()
# Out:
# np.float64(3.5219747500000005)

# %%
s2 = s.loc[[2,3,6,7,10,11,12,13,14,15,16,17]]

# %%
s2 = s2.copy().reset_index(drop=True)

# %%
s2.to_csv("testreport.csv")
