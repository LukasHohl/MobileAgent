# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("token_usage.csv")

# %%
df["task_id"] = df["task_id"].replace("20250215-120903", "survery Large Language Model papers")

# %%
df
# Out:
#       prompt_tokens  completion_tokens  cached_tokens  \
# 0              9891                527              0
# 1              1816                258              0
# 2              3548                106              0
# 3              9559                466              0
# 4              9891                558              0
# ...             ...                ...            ...
# 1075           1757                162              0
# 1076           3694                134              0
# 1077         153558                389              0
# 1078           4287                 67              0
# 1079           2161                 10              0
#
#                                   task_id              model
# 0                         20250215-120638        gpt-4o-mini
# 1                         20250215-120638  gpt-4o-2024-11-20
# 2                         20250215-120638  gpt-4o-2024-11-20
# 3                         20250215-120638        gpt-4o-mini
# 4     survery Large Language Model papers        gpt-4o-mini
# ...                                   ...                ...
# 1075                                   10  gpt-4o-2024-11-20
# 1076                                   10  gpt-4o-2024-11-20
# 1077                                   10        gpt-4o-mini
# 1078                                   10  gpt-4o-2024-11-20
# 1079                                   10  gpt-4o-2024-11-20
#
# [1080 rows x 5 columns]

# %%
s = df.groupby(by=["task_id","model"]).sum()

# %%
type(s)
# Out:
# pandas.core.frame.DataFrame

# %%
s= s.reset_index(drop=False)

# %%
s
# Out:
#                                 task_id              model  prompt_tokens  \
# 0                                     0  gpt-4o-2024-11-20         183345
# 1                                     0        gpt-4o-mini        3927063
# 2                                     1  gpt-4o-2024-11-20         273958
# 3                                     1        gpt-4o-mini        4535445
# 4                                    10  gpt-4o-2024-11-20         145020
# 5                                    10        gpt-4o-mini        2678734
# 6                1_bakery_birthday_cake  gpt-4o-2024-11-20          21700
# 7                1_bakery_birthday_cake        gpt-4o-mini          26847
# 8              1_late_night_korean_food  gpt-4o-2024-11-20         351869
# 9              1_late_night_korean_food        gpt-4o-mini         381906
# 10                     1_nearest_bakery  gpt-4o-2024-11-20          22589
# 11                     1_nearest_bakery        gpt-4o-mini          41919
# 12                          1_thai_duck  gpt-4o-2024-11-20         255280
# 13                          1_thai_duck        gpt-4o-mini         241430
# 14                                    2  gpt-4o-2024-11-20         171726
# 15                                    2        gpt-4o-mini        2758316
# 16                      20250215-120638  gpt-4o-2024-11-20           5364
# 17                      20250215-120638        gpt-4o-mini          19450
# 18                  2_llm_agents_survey  gpt-4o-2024-11-20         143199
# 19                  2_llm_agents_survey        gpt-4o-mini         102244
# 20                    2_recipes_chinese  gpt-4o-2024-11-20          45650
# 21                    2_recipes_chinese        gpt-4o-mini          45162
# 22             2_segment_anything_cited  gpt-4o-2024-11-20         182018
# 23             2_segment_anything_cited        gpt-4o-mini         136187
# 24                                    3  gpt-4o-2024-11-20         111191
# 25                                    3        gpt-4o-mini        1748855
# 26                                    4  gpt-4o-2024-11-20         144461
# 27                                    4        gpt-4o-mini        2448397
# 28                                    5  gpt-4o-2024-11-20          94480
# 29                                    5        gpt-4o-mini        1629421
# 30                                    6  gpt-4o-2024-11-20         121725
# 31                                    6        gpt-4o-mini        1945068
# 32                                    7  gpt-4o-2024-11-20         147580
# 33                                    7        gpt-4o-mini        1797116
# 34                                    8  gpt-4o-2024-11-20          58783
# 35                                    8        gpt-4o-mini         855903
# 36                                    9  gpt-4o-2024-11-20         106857
# 37                                    9        gpt-4o-mini        1484394
# 38  survery Large Language Model papers  gpt-4o-2024-11-20         121959
# 39  survery Large Language Model papers        gpt-4o-mini          83124
#
#     completion_tokens  cached_tokens
# 0                6712              0
# 1               10664              0
# 2                9057              0
# 3               11936              0
# 4                4914              0
# 5                6607              0
# 6                 686              0
# 7                1439              0
# 8               13742              0
# 9               18734              0
# 10                625              0
# 11               2188              0
# 12              10780              0
# 13              11616              0
# 14               6014              0
# 15               7100              0
# 16                364              0
# 17                993              0
# 18               5184              0
# 19               4879              0
# 20               1516              0
# 21               2175              0
# 22               6398              0
# 23               6468              0
# 24               5033              0
# 25               4663              0
# 26               5523              0
# 27               6471              0
# 28               3908              0
# 29               4176              0
# 30               5109              0
# 31               4987              0
# 32               7569              0
# 33               4369              0
# 34               4349              0
# 35               2118              0
# 36               3962              0
# 37               3670              0
# 38               6170              0
# 39               4032              0

# %%
def cost_function(row):
    if (row["model"] == "gpt-4o-mini"):
        return row["prompt_tokens"]* 0.15/1000000.0 + 0.6 /1000000.0 * row["completion_tokens"]
    else:
        return row["prompt_tokens"]* 2.5/1000000.0 + 10.0 /1000000.0 * row["completion_tokens"]

# %%
s["cost"] = s.apply(cost_function, axis= 1)

# %%
s
# Out:
#                                 task_id              model  prompt_tokens  \
# 0                                     0  gpt-4o-2024-11-20         183345
# 1                                     0        gpt-4o-mini        3927063
# 2                                     1  gpt-4o-2024-11-20         273958
# 3                                     1        gpt-4o-mini        4535445
# 4                                    10  gpt-4o-2024-11-20         145020
# 5                                    10        gpt-4o-mini        2678734
# 6                1_bakery_birthday_cake  gpt-4o-2024-11-20          21700
# 7                1_bakery_birthday_cake        gpt-4o-mini          26847
# 8              1_late_night_korean_food  gpt-4o-2024-11-20         351869
# 9              1_late_night_korean_food        gpt-4o-mini         381906
# 10                     1_nearest_bakery  gpt-4o-2024-11-20          22589
# 11                     1_nearest_bakery        gpt-4o-mini          41919
# 12                          1_thai_duck  gpt-4o-2024-11-20         255280
# 13                          1_thai_duck        gpt-4o-mini         241430
# 14                                    2  gpt-4o-2024-11-20         171726
# 15                                    2        gpt-4o-mini        2758316
# 16                      20250215-120638  gpt-4o-2024-11-20           5364
# 17                      20250215-120638        gpt-4o-mini          19450
# 18                  2_llm_agents_survey  gpt-4o-2024-11-20         143199
# 19                  2_llm_agents_survey        gpt-4o-mini         102244
# 20                    2_recipes_chinese  gpt-4o-2024-11-20          45650
# 21                    2_recipes_chinese        gpt-4o-mini          45162
# 22             2_segment_anything_cited  gpt-4o-2024-11-20         182018
# 23             2_segment_anything_cited        gpt-4o-mini         136187
# 24                                    3  gpt-4o-2024-11-20         111191
# 25                                    3        gpt-4o-mini        1748855
# 26                                    4  gpt-4o-2024-11-20         144461
# 27                                    4        gpt-4o-mini        2448397
# 28                                    5  gpt-4o-2024-11-20          94480
# 29                                    5        gpt-4o-mini        1629421
# 30                                    6  gpt-4o-2024-11-20         121725
# 31                                    6        gpt-4o-mini        1945068
# 32                                    7  gpt-4o-2024-11-20         147580
# 33                                    7        gpt-4o-mini        1797116
# 34                                    8  gpt-4o-2024-11-20          58783
# 35                                    8        gpt-4o-mini         855903
# 36                                    9  gpt-4o-2024-11-20         106857
# 37                                    9        gpt-4o-mini        1484394
# 38  survery Large Language Model papers  gpt-4o-2024-11-20         121959
# 39  survery Large Language Model papers        gpt-4o-mini          83124
#
#     completion_tokens  cached_tokens      cost
# 0                6712              0  0.525482
# 1               10664              0  0.595458
# 2                9057              0  0.775465
# 3               11936              0  0.687478
# 4                4914              0  0.411690
# 5                6607              0  0.405774
# 6                 686              0  0.061110
# 7                1439              0  0.004890
# 8               13742              0  1.017092
# 9               18734              0  0.068526
# 10                625              0  0.062723
# 11               2188              0  0.007601
# 12              10780              0  0.746000
# 13              11616              0  0.043184
# 14               6014              0  0.489455
# 15               7100              0  0.418007
# 16                364              0  0.017050
# 17                993              0  0.003513
# 18               5184              0  0.409838
# 19               4879              0  0.018264
# 20               1516              0  0.129285
# 21               2175              0  0.008079
# 22               6398              0  0.519025
# 23               6468              0  0.024309
# 24               5033              0  0.328307
# 25               4663              0  0.265126
# 26               5523              0  0.416382
# 27               6471              0  0.371142
# 28               3908              0  0.275280
# 29               4176              0  0.246919
# 30               5109              0  0.355403
# 31               4987              0  0.294752
# 32               7569              0  0.444640
# 33               4369              0  0.272189
# 34               4349              0  0.190447
# 35               2118              0  0.129656
# 36               3962              0  0.306762
# 37               3670              0  0.224861
# 38               6170              0  0.366598
# 39               4032              0  0.014888

# %%
s["cost"].sum()
# Out:
# np.float64(11.95265315)

# %%
s2 = s.loc[[2,3,6,7,10,11,12,13,14,15,16,17]]

# %%
s2 = s2.copy().reset_index(drop=True)

# %%
s2.to_csv("testreport.csv")
